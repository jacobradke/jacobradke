# %%
import pandas as pd
import numpy as np
import pandas_datareader as web
import matplotlib.pyplot as plt
import datetime
#imported a library that I created so that I wouldn't clutter this notebook
from mylib.mean_variance import *
import statsmodels.api as sm
from datlib.FRED import *
from datlib.plots import *
benchmark = "^GSPC"
plt.rcParams.update({"font.size":40})
start = datetime.datetime(2011,1,1)
end = datetime.datetime.today()
rf = web.DataReader("^TNX", "yahoo", start = datetime.datetime(2021,10,1), end = end)["Adj Close"]
rf = pd.DataFrame(rf)
ticker_lst = ["XLK", "XLY", "XLRE", "XLV", "XLP", "XLE", "XLF", "XLI", "XLC", "BND", "SUB"]

# %%
portfolios = mean_variance(ticker_lst, 
                           num_ports = 50000, 
                           start = start, 
                           end = end, 
                           benchmark = benchmark,
                           rf = rf["Adj Close"][-1])
portfolios
# Out:
#          Returns  Volatility  Sharpe Ratio  Portfolio Beta  Jensen's Alpha  \
# 0      11.039910   12.663920      0.754183        0.709094        0.184732
# 1       9.358818   13.339476      0.589965        0.749145       -2.025370
# 2      10.226092   12.368021      0.706426        0.712808       -0.678133
# 3      12.274250   14.685818      0.734399        0.834897       -0.242615
# 4      10.925307   12.451115      0.757868        0.706409        0.105604
# ...          ...         ...           ...             ...             ...
# 49995  11.899350   13.500097      0.771132        0.772177        0.210938
# 49996  10.666457   12.380962      0.741256        0.697766       -0.039090
# 49997  11.842856   15.414736      0.671686        0.879558       -1.263915
# 49998  10.807157   13.735090      0.678420        0.773297       -0.896056
# 49999  12.106651   12.575729      0.844297        0.718286        1.130068
#
#        Information Ratio  XLK Weight  XLY Weight  XLRE Weight  XLV Weight  \
# 0              -0.176044    0.127491    0.098472     0.050221    0.003071
# 1              -0.181536    0.048698    0.103556     0.089796    0.052363
# 2              -0.095161    0.119037    0.112166     0.018896    0.139550
# 3              -0.134903    0.104506    0.050314     0.051596    0.100420
# 4              -0.185604    0.002828    0.124666     0.029891    0.114414
# ...                  ...         ...         ...          ...         ...
# 49995          -0.097103    0.127521    0.163105     0.053243    0.011158
# 49996          -0.194374    0.082372    0.048081     0.095701    0.110705
# 49997          -0.064395    0.039633    0.147816     0.006212    0.184760
# 49998          -0.155079    0.003048    0.164904     0.123151    0.121845
# 49999          -0.161305    0.074528    0.099427     0.020563    0.074943
#
#        XLP Weight  XLE Weight  XLF Weight  XLI Weight  XLC Weight  BND Weight  \
# 0        0.151207    0.172929    0.000760    0.051841    0.154430    0.114702
# 1        0.138605    0.158325    0.038526    0.141881    0.036746    0.051103
# 2        0.150413    0.085500    0.030052    0.096436    0.000056    0.086341
# 3        0.124258    0.153554    0.147312    0.050448    0.121975    0.012019
# 4        0.103736    0.112046    0.124389    0.051933    0.124056    0.120117
# ...           ...         ...         ...         ...         ...         ...
# 49995    0.056492    0.108766    0.069828    0.129655    0.084267    0.075166
# 49996    0.104980    0.142664    0.044282    0.051073    0.126700    0.048739
# 49997    0.147869    0.114732    0.201390    0.047351    0.008738    0.005633
# 49998    0.104973    0.148102    0.069043    0.064337    0.073328    0.024464
# 49999    0.221880    0.089702    0.029106    0.091256    0.152195    0.012234
#
#        SUB Weight
# 0        0.074876
# 1        0.140400
# 2        0.161553
# 3        0.083598
# 4        0.091923
# ...           ...
# 49995    0.120798
# 49996    0.144704
# 49997    0.095866
# 49998    0.102804
# 49999    0.134166
#
# [50000 rows x 17 columns]

# %%
efficient_frontier(portfolios, 
                   benchmark = benchmark, 
                   alpha = .4, 
                   rf = rf["Adj Close"][-1], 
                   start = start, 
                   end = end, 
                   figsize = (24,18))

# %%
sharpe_portfolio = optimal_sharpe_portfolio(
    portfolios, 
    rf = rf["Adj Close"][-1])
sharpe_portfolio
# Out:
#         Returns  Volatility  Sharpe Ratio  Portfolio Beta  Jensen's Alpha  \
# 11839  16.97543   12.789701      1.210852        0.687427        6.406445
#
#        Information Ratio  XLK Weight  XLY Weight  XLRE Weight  XLV Weight  \
# 11839          -0.137377    0.098501    0.195617      0.16861    0.001507
#
#        XLP Weight  XLE Weight  XLF Weight  XLI Weight  XLC Weight  BND Weight  \
# 11839    0.026823     0.01859    0.051449    0.011932     0.36254     0.01103
#
#        SUB Weight
# 11839    0.053402

# %%
jensens_portfolio = optimal_jensens_alpha(portfolios)
jensens_portfolio
# Out:
#         Returns  Volatility  Sharpe Ratio  Portfolio Beta  Jensen's Alpha  \
# 11839  16.97543   12.789701      1.210852        0.687427        6.406445
#
#        Information Ratio  XLK Weight  XLY Weight  XLRE Weight  XLV Weight  \
# 11839          -0.137377    0.098501    0.195617      0.16861    0.001507
#
#        XLP Weight  XLE Weight  XLF Weight  XLI Weight  XLC Weight  BND Weight  \
# 11839    0.026823     0.01859    0.051449    0.011932     0.36254     0.01103
#
#        SUB Weight
# 11839    0.053402
