# %% [markdown]
# # Advanced Data Analysis

# %%
import pandas as pd
import pandas_datareader as web
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_excel("mpd2018.xlsx", 
                     sheet_name = "Full data", 
                     index_col = [0,2])
data
# Out:
#                       country  cgdppc  rgdpnapc      pop         i_cig i_bm
# countrycode year
# AFG         1820  Afghanistan     NaN       NaN   3280.0           NaN  NaN
#             1870  Afghanistan     NaN       NaN   4207.0           NaN  NaN
#             1913  Afghanistan     NaN       NaN   5730.0           NaN  NaN
#             1950  Afghanistan  2392.0    2392.0   8150.0  Extrapolated  NaN
#             1951  Afghanistan  2422.0    2422.0   8284.0  Extrapolated  NaN
# ...                       ...     ...       ...      ...           ...  ...
# ZWE         2012     Zimbabwe  1623.0    1604.0  12620.0  Extrapolated  NaN
#             2013     Zimbabwe  1801.0    1604.0  13183.0  Extrapolated  NaN
#             2014     Zimbabwe  1797.0    1594.0  13772.0  Extrapolated  NaN
#             2015     Zimbabwe  1759.0    1560.0  14230.0  Extrapolated  NaN
#             2016     Zimbabwe  1729.0    1534.0  14547.0  Extrapolated  NaN
#
# [19873 rows x 6 columns]

# %% [markdown]
# #### list of years

# %%
years = list(set(data.index.get_level_values("year")))
years
# Out:
# [1,
#  730,
#  1000,
#  1150,
#  1280,
#  1281,
#  1282,
#  1283,
#  1284,
#  1285,
#  1286,
#  1287,
#  1288,
#  1289,
#  1290,
#  1291,
#  1292,
#  1293,
#  1294,
#  1295,
#  1296,
#  1297,
#  1298,
#  1299,
#  1300,
#  1301,
#  1302,
#  1303,
#  1304,
#  1305,
#  1306,
#  1307,
#  1308,
#  1309,
#  1310,
#  1311,
#  1312,
#  1313,
#  1314,
#  1315,
#  1316,
#  1317,
#  1318,
#  1319,
#  1320,
#  1321,
#  1322,
#  1323,
#  1324,
#  1325,
#  1326,
#  1327,
#  1328,
#  1329,
#  1330,
#  1331,
#  1332,
#  1333,
#  1334,
#  1335,
#  1336,
#  1337,
#  1338,
#  1339,
#  1340,
#  1341,
#  1342,
#  1343,
#  1344,
#  1345,
#  1346,
#  1347,
#  1348,
#  1349,
#  1350,
#  1351,
#  1352,
#  1353,
#  1354,
#  1355,
#  1356,
#  1357,
#  1358,
#  1359,
#  1360,
#  1361,
#  1362,
#  1363,
#  1364,
#  1365,
#  1366,
#  1367,
#  1368,
#  1369,
#  1370,
#  1371,
#  1372,
#  1373,
#  1374,
#  1375,
#  1376,
#  1377,
#  1378,
#  1379,
#  1380,
#  1381,
#  1382,
#  1383,
#  1384,
#  1385,
#  1386,
# ...

# %% [markdown]
# #### Mean of every country's data

# %%
data.groupby('countrycode').mean()
# Out:
#                    cgdppc      rgdpnapc           pop
# countrycode
# AFG           2042.626866   2042.626866  16274.685714
# AGO           3572.738095   5097.500000   8439.746269
# ALB           4107.191781   4351.205479   1889.220183
# ARE          83268.875000  97724.291667   2316.283582
# ARG           9022.068027   9191.326531  20976.983471
# ...                   ...           ...           ...
# YEM           2325.417910   3061.283582  12267.057143
# YUG           4755.073684   7036.452632  17728.378641
# ZAF           4023.770909   4571.992727  29526.453333
# ZMB           1785.731343   2647.955224   7373.552239
# ZWE           2766.268657   1841.880597   8150.970149
#
# [169 rows x 3 columns]

# %% [markdown]
# #### List of countries

# %%
countries = list(data.groupby('countrycode').mean().index)
countries
# Out:
# ['AFG',
#  'AGO',
#  'ALB',
#  'ARE',
#  'ARG',
#  'ARM',
#  'AUS',
#  'AUT',
#  'AZE',
#  'BDI',
#  'BEL',
#  'BEN',
#  'BFA',
#  'BGD',
#  'BGR',
#  'BHR',
#  'BIH',
#  'BLR',
#  'BOL',
#  'BRA',
#  'BRB',
#  'BWA',
#  'CAF',
#  'CAN',
#  'CHE',
#  'CHL',
#  'CHN',
#  'CIV',
#  'CMR',
#  'COD',
#  'COG',
#  'COL',
#  'COM',
#  'CPV',
#  'CRI',
#  'CSK',
#  'CUB',
#  'CYP',
#  'CZE',
#  'DEU',
#  'DJI',
#  'DMA',
#  'DNK',
#  'DOM',
#  'DZA',
#  'ECU',
#  'EGY',
#  'ESP',
#  'EST',
#  'ETH',
#  'FIN',
#  'FRA',
#  'GAB',
#  'GBR',
#  'GEO',
#  'GHA',
#  'GIN',
#  'GMB',
#  'GNB',
#  'GNQ',
#  'GRC',
#  'GTM',
#  'HKG',
#  'HND',
#  'HRV',
#  'HTI',
#  'HUN',
#  'IDN',
#  'IND',
#  'IRL',
#  'IRN',
#  'IRQ',
#  'ISL',
#  'ISR',
#  'ITA',
#  'JAM',
#  'JOR',
#  'JPN',
#  'KAZ',
#  'KEN',
#  'KGZ',
#  'KHM',
#  'KOR',
#  'KWT',
#  'LAO',
#  'LBN',
#  'LBR',
#  'LBY',
#  'LCA',
#  'LKA',
#  'LSO',
#  'LTU',
#  'LUX',
#  'LVA',
#  'MAR',
#  'MDA',
#  'MDG',
#  'MEX',
#  'MKD',
#  'MLI',
# ...

# %% [markdown]
# #### Plot data by country

# %%
pairs = [("USA", "CAN"), 
         ("VEN", "MEX"), 
         ("NOR", "FIN", "DNK", "NLD")]
linestyles = ["-", ":", "--", "-."]

# %%
plt.rcParams.update({"font.size": 32})
plt.rcParams.update({"legend.fontsize": 25, 
                     "legend.handlelength": 2})
for pair in pairs:
    fig, ax = plt.subplots(figsize = (20,10))
    for i in range(len(pair)):
        country = pair[i]
        linestyle = linestyles[i]
        data.loc[country, :]["cgdppc"].dropna().plot.line(ax = ax,
                                                          label = country,
                                                          linestyle = linestyle)
    plt.xlim([1825, max(years)])
    plt.ylabel("$Real$ $GDP$ $Per$ $Capita$\n2011 U.S. Dollars")
    plt.legend()
    plt.show()
    plt.close()

# %% [markdown]
# ## Merging Data Sets with Double Index

# %%
fraser_data = pd.read_csv("cleanedEconFreedomData.csv", 
                          index_col = [0,1], 
                          parse_dates = False)
fraser_data = fraser_data.dropna(axis = 0,
                                 thresh = 1).dropna(axis = 1, 
                                                    thresh = 1)
# thresh = 1 is like how = "all"
maddison_data = data
fraser_data
# Out:
#                     EFW  Size Of Government  Legal System & Property Rights  \
# ISO_Code Year
# ALB      2017  7.673511            7.528167                        5.064907
#          2016  7.637742            7.875862                        5.071814
#          2015  7.639666            7.904257                        5.003489
#          2014  7.586769            7.882037                        4.666740
#          2013  7.389525            7.807904                        4.543782
# ...                 ...                 ...                             ...
# ZWE      2000  4.299839            5.365058                        4.662445
#          1995  5.518614            6.418859                        5.138131
#          1990  4.516140            5.108843                        3.439437
#          1985  4.226841            5.026250                        2.633492
#          1980  4.054740            6.322625                        1.379602
#
# ...

# %%
fraser_data["RGDP Per Capita"] = maddison_data["rgdpnapc"]
fraser_data.to_csv("fraserdatawRDGPC.csv")

# %% [markdown]
# ## Create an indicator variable

# %%
def create_indicator_variable(data, 
                              indicator_name, 
                              index_name, 
                              target_index_list):
    # prepare a column with the name of the indicator variable
    data[indicator_name] = 0
    # for each index whose name matches the entry in target_index_list
    # a 1 will be recorded
    for index in target_index_list:
        # check if ISO code of row matches the ISO Code from the target index list
        # set value of the indicator name (column) to 1 for all rows
        data.loc[index, [indicator_name]] = round(int(1),0)
        
data = fraser_data
index_name = data.index.names[0]
indicator_names = "North America"
# Cuba, Grenada, Saint Kitts, Saint Lucia, Saint Vincent are missing
countries_in_north_america = ["BHS", "BRB", "BLZ", "CAN", 
                              "CRI", "DOM", "SLV", "GTM", 
                              "HTI", "HND", "JAM", "MEX", 
                              "NIC", "PAN", "TTO", "USA"] 
create_indicator_variable(data = data, 
                          indicator_name = indicator_names, 
                          index_name = index_name, 
                          target_index_list = countries_in_north_america)

# %%
data.loc[countries_in_north_america, "North America"]
# Out:
# ISO_Code  Year
# BHS       2017    1.0
#           2016    1.0
#           2015    1.0
#           2014    1.0
#           2013    1.0
#                  ...
# USA       1990    1.0
#           1985    1.0
#           1980    1.0
#           1975    1.0
#           1970    1.0
# Name: North America, Length: 323, dtype: float64

# %% [markdown]
# #### Ploting Countries

# %%
import datetime
year = 2009
plot_data = data[data.index.get_level_values("Year") == year]
fig, ax = plt.subplots(figsize = (24,12))
plot_data.plot.scatter(x = "EFW", 
                       y = "RGDP Per Capita", 
                       c = "North America", 
                       cmap = "coolwarm", 
                       ax = ax, 
                       s = 55)
ax.set_title(str(year), fontsize = 50)
plt.show()
plt.close()

# %%
from matplotlib import cm

year = 2009

norm = cm.colors.Normalize()
cmap = cm.get_cmap('coolwarm', 
                   2)
plt.cm.ScalarMappable(cmap=cmap, 
                      norm=norm)

plot_data = data[data.index.get_level_values("Year") == year]
fig, ax = plt.subplots(figsize = (24, 16))
plot_data.plot.scatter(x = "EFW", 
                       y = "RGDP Per Capita", 
                       c = "North America",
                       cmap = cmap, 
                       ax = ax, 
                       #norm = norm, 
                       s = 50)
# Out:
# <AxesSubplot:xlabel='EFW', ylabel='RGDP Per Capita'>

# %%
plot_data
# Out:
# Empty DataFrame
# Columns: [EFW, Size Of Government, Legal System & Property Rights, Sound Money, Freedom To Trade Internationally, Regulation, RGDP Per Capita, North America, RGDP Per Capita 10-tile]
# Index: []

# %%
n = 10
quantile_var = "RGDP Per Capita"
quantile_name = quantile_var + " " + str(n) + "-tile"
data[quantile_name] = np.nan
data
# Out:
#                     EFW  Size Of Government  Legal System & Property Rights  \
# ISO_Code Year
# ALB      2017  7.673511            7.528167                        5.064907
#          2016  7.637742            7.875862                        5.071814
#          2015  7.639666            7.904257                        5.003489
#          2014  7.586769            7.882037                        4.666740
#          2013  7.389525            7.807904                        4.543782
# ...                 ...                 ...                             ...
# ZWE      1995  5.518614            6.418859                        5.138131
#          1990  4.516140            5.108843                        3.439437
#          1985  4.226841            5.026250                        2.633492
#          1980  4.054740            6.322625                        1.379602
# BRB                 NaN                 NaN                             NaN
#
# ...

# %% [markdown]
# ### What this is doing

# %%
def create_quantile(n, data, year, quantile_var, quantile_name):
    # year becuase we have panel data and we want to look at that given year
    year_index = data.index.get_level_values("Year") == year
    return data.loc[year_index]

# %%
create_quantile(n = n, 
                data = data, 
                year = year, 
                quantile_var = quantile_var, 
                quantile_name = quantile_name)
# Out:
#                     EFW  Size Of Government  Legal System & Property Rights  \
# ISO_Code Year
# ALB      2000  6.296170            7.260723                        4.585351
# DZA      2000  4.796785            4.236876                        3.295760
# ARG      2000  7.218572            8.001421                        4.757417
# AUS      2000  8.105358            6.815197                        8.530602
# AUT      2000  8.002885            5.464242                        8.613877
# ...                 ...                 ...                             ...
# USA      2000  8.518073            7.376862                        8.472453
# URY      2000  6.993437            6.371031                        5.758478
# VEN      2000  5.683733            5.715487                        3.916083
# ZMB      2000  6.360364            6.084279                        5.286878
# ZWE      2000  4.299839            5.365058                        4.662445
#
# ...

# %% [markdown]
# ## Continue

# %%
def create_quantile(n, data, year, quantile_var, quantile_name):
    # year becuase we have panel data and we want to look at that given year
    year_index = data.index.get_level_values("Year") == year
    year_data = data[year_index][quantile_var]
    # select the subset of the data frame by year and variable of interest
    quantile_values_dct = {i:year_data.quantile(i/n) for i in range(1, n+1)}
    for index in data[year_index].index:
        # identify value of the variable of interest
        val = data.loc[index][quantile_var]
        # compare that value to the values that divide each quantile
        for i in range(1, n+1):
            if val <= quantile_values_dct[i]:
                data.loc[index, [quantile_name]] = int((n+1) - i)
                break
            else:
                continue
years = data.groupby("Year").mean().index
for year in years:
    create_quantile(n, 
                   data, 
                   year, 
                   quantile_var,   
                   quantile_name)

# %%
data.loc["MEX"]["RGDP Per Capita 10-tile"]
# Out:
# Year
# 2017    NaN
# 2016    5.0
# 2015    5.0
# 2014    5.0
# 2013    5.0
# 2012    5.0
# 2011    5.0
# 2010    5.0
# 2009    5.0
# 2008    5.0
# 2007    5.0
# 2006    5.0
# 2005    4.0
# 2004    5.0
# 2003    5.0
# 2002    4.0
# 2001    5.0
# 2000    4.0
# 1995    5.0
# 1990    4.0
# 1985    4.0
# 1980    5.0
# 1975    7.0
# Name: RGDP Per Capita 10-tile, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (20,10))
for country in ["FIN", "DNK", "DNK", "NOR", "GBR"]:
    data.loc[country]["RGDP Per Capita 10-tile"].plot.line(ax = ax, label = country)
plt.legend()

# %%
year = 2009
from mpl_toolkits.axes_grid1 import make_axes_locatable
plot_data = data[data.index.get_level_values("Year")== year]
fig, ax = plt.subplots(figsize = (24, 16))
norm = cm.colors.Normalize()
cmap = cm.get_cmap("jet", n)
plt.cm.ScalarMappable(cmap = cmap, 
                      norm = norm)
plot_data.plot.scatter(x = "EFW", 
                       y = "RGDP Per Capita", 
                       c = "RGDP Per Capita " + str(n) + "-tile", 
                       cmap = cmap,
                       #norm = norm,
                       ax = ax,
                       s = 50, 
                       legend = False, 
                       vmin = 0.5, 
                       vmax = n+0.5)
ax.set_title(str(year) + " Data", fontsize = 40)
# Out:
# Text(0.5, 1.0, '2009 Data')

# %% [markdown]
# ## Lag Variables and Differenced Log Values

# %%
data["RGDP Per Capita Lag"] = data.groupby(level = "ISO_Code")["RGDP Per Capita"].shift(-1)
data.loc["NOR",:]
